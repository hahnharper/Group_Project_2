# %%
import pandas as pd

# %%
data = pd.read_json("./static/data/B_Project1.json")

# %%
data.columns = data.iloc[0]

# %%
data.to_json("./static/data/B_Project2.json")
# Out:
# Year                   2019     2019      2019        2019      2019  \
# Year                   2019     2019      2019        2019      2019
# Quarter                  Q1       Q1        Q1          Q1        Q1
# State               Alabama  Arizona  Arkansas  California  Colorado
# Colonies               7500    25000     22000    1.15e+06     13000
# Max Colonies           7500    26000     22000     1540000     21000
# Lost Colonies           820     6000      7500      215000      4900
# Added Colonies         1200      810       540      205000      1400
# Renovated Colonies     1500      230       810      133000       190
#
# Year                       2019     2019     2019    2019    2019  ...  \
# Year                       2019     2019     2019    2019    2019  ...
# Quarter                      Q1       Q1       Q1      Q1      Q1  ...
# State               Connecticut  Florida  Georgia  Hawaii   Idaho  ...
# ...
